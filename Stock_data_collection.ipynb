# %% [markdown]
# <a href="https://colab.research.google.com/github/Deleon57/EDAR-Data/blob/main/Stock_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr

# %%
stocklist = ['GFI', 'FSR']
stocks = [i + '.JO' for i in stocklist]
stocks
# Out:
# ['GFI.JO', 'FSR.JO']

# %%
import yfinance as yf
import pandas as pd


start = "2013-03-01"
end = "2024-02-28"


df = yf.download(['GFI.JO', 'FSR.JO'], start=start, end=end)

df.head()
# Out:
# /tmp/ipython-input-1439549182.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['GFI.JO', 'FSR.JO'], start=start, end=end)
# [*********************100%***********************]  2 of 2 completed
# Price             Close                      High                       Low  \
# Ticker           FSR.JO       GFI.JO       FSR.JO       GFI.JO       FSR.JO
# Date
# 2013-03-01  3121.474121  7431.279785  3132.409222  7503.098865  3062.822219
# 2013-03-04  3064.810059  7250.467773  3126.444254  7385.142120  3032.004761
# 2013-03-05  3201.001953  7257.450684  3201.001953  7283.387964  3083.698155
# 2013-03-06  3107.556396  6928.247559  3220.883789  7299.350236  3105.568197
# 2013-03-07  3114.515137  7453.975586  3156.267335  7503.854973  3095.627238
#
# Price                           Open                 Volume
# Ticker           GFI.JO       FSR.JO       GFI.JO    FSR.JO    GFI.JO
# Date
# 2013-03-01  7338.513474  3084.692420  7465.194351  12379894   5930842
# 2013-03-04  7250.467773  3126.444254  7370.178304  14174847   4128626
# 2013-03-05  7217.547175  3100.597855  7262.438622  16391688   5666832
# 2013-03-06  6928.247559  3202.989990  7258.449134  18189945   6130247
# 2013-03-07  7237.499047  3132.408936  7282.390495  18272095  10489933

# %%
Close = df['Close']
Close.head()
# Out:
# Ticker           FSR.JO       GFI.JO
# Date
# 2013-03-01  3121.474121  7431.279785
# 2013-03-04  3064.810059  7250.467773
# 2013-03-05  3201.001953  7257.450684
# 2013-03-06  3107.556396  6928.247559
# 2013-03-07  3114.515137  7453.975586

# %%
Close.describe()
# Out:
# Ticker       FSR.JO        GFI.JO
# count   2797.000000   2797.000000
# mean    5337.168545  10039.145357
# std     1178.805931   7137.429973
# min     2621.901855   3092.964844
# 25%     4488.130859   4661.727539
# 50%     5316.082520   6090.257812
# 75%     6400.090820  14596.770508
# max     7759.539551  32293.537109

# %%
Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>
